# %% [markdown]
# ### This is an experiment for new image-text retrieval web ###
# NOTES:
# - This experiment uses AWS S3 cloud service to store and retrieve AIC datas

# %% [markdown]
# **SETUP**

# %%
import boto3
import os
from tqdm import tqdm

# %% [markdown]
# **S3 SETUP**

# %%
s3 = boto3.client(
    's3',
    region_name='ap-southeast-2',
    aws_access_key_id='AKIAQDPHTGR3B5QJOU6M',
    aws_secret_access_key='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',
)

s3.put_bucket_accelerate_configuration(
    Bucket='aic2025',
    AccelerateConfiguration={
        'Status': 'Enabled'
    }
)
# Out:
# {'ResponseMetadata': {'RequestId': 'DDVJ4089KMFW3N9G',
#   'HostId': 'VglNnM9/Mh/0epfHdk0ZGWuqb2asTmpjjQYXSNHoUC9aYJzz/tDKQDLBKRuRtNtW2EUGlRmIJf0=',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amz-id-2': 'VglNnM9/Mh/0epfHdk0ZGWuqb2asTmpjjQYXSNHoUC9aYJzz/tDKQDLBKRuRtNtW2EUGlRmIJf0=',
#    'x-amz-request-id': 'DDVJ4089KMFW3N9G',
#    'date': 'Mon, 25 Aug 2025 14:41:21 GMT',
#    'content-length': '0',
#    'server': 'AmazonS3'},
#   'RetryAttempts': 0}}

# %% [markdown]
# **UPLOAD IMAGE DIRS TO S3**

# %%
dir_path = 'D:\\kfs'
bucket = 'aic2025'
with tqdm(list(os.walk(dir_path))) as t:
    for root, _, file in t:
        if len(root) <= 30: continue
        
        obj = root.split('\\')
        for f in file:
            filename = root + '\\' + f
            key = obj[1] + '/' + obj[2] +'/' + obj[4] + '/' + f
            print(filename)
            print(key)
            # s3.upload_file(filename, bucket, key)

# %% [markdown]
# **UPLOAD A SPECIFIC FILE TO S3**

# %%
filename = 'dataset-aic2025-no-feature.pt'
bucket = 'aic2025'
key = 'datasets/dataset-aic2025-no-feature-b1.pt'
s3.upload_file(filename, bucket, key)
