# %% [markdown]
# **SETUP**

# %%
import torch
from pprint import pprint

# %% [markdown]
# **NO FEATURE**

# %%
b1 = torch.load('aic_2025-b1.pt')
b2 = torch.load('aic_2025-b2.pt')
torch.save(b1 | b2, 'aic_2025.pt')

# %%
b1 = torch.load('aic_2025-wfeat-b1.pt')
b2 = torch.load('aic_2025-wfeat-b2.pt')
torch.save(b1 | b2, 'aic_2025-wfeat.pt')

# %%
full = b1 | b2

# %%
pprint(list(full.values())[333333])
# Out:
# {'answer_key': 'K16_V012-507967',
#  'fps': '30.0',
#  'frame_id': '171',
#  'frame_order': '15239',
#  'img_link': 'https://storage.cloud.google.com/aic_2025/kfs/Keyframes_K16/K16_V012/171.jpg',
#  'publish_date': '22/05/2025',
#  'time_order': '507967',
#  'vector': [0.010746925137937069,
#             1.455959863960743e-05,
#             0.012618319131433964,
#             0.04174528270959854,
#             -0.008766819722950459,
#             -0.005039562471210957,
#             0.0017898599617183208,
#             -0.0035078926011919975,
#             0.01667947694659233,
#             0.03646500036120415,
#             0.01542152650654316,
#             -0.017642350867390633,
#             0.043888453394174576,
#             -0.008906591683626175,
#             0.01758022978901863,
#             0.009582157246768475,
#             -0.013387065380811691,
#             0.010537266731262207,
#             -0.021897636353969574,
#             0.014272289350628853,
# ...
