# %%
import torch
import random
from torchvision import transforms
from open_clip import create_model_from_pretrained, get_tokenizer
from datasets import load_dataset

device = 'cuda' if torch.cuda.is_available() else 'cpu'
model, preprocess = create_model_from_pretrained('hf-hub:apple/DFN5B-CLIP-ViT-H-14-384')
tokenizer = get_tokenizer('ViT-H-14')
model.to(device)

coco = load_dataset('lmms-lab/COCO-Caption2017')

# %%
print(coco)
# Out:
# DatasetDict({
#     val: Dataset({
#         features: ['question_id', 'image', 'question', 'answer', 'id', 'license', 'file_name', 'coco_url', 'height', 'width', 'date_captured'],
#         num_rows: 5000
#     })
#     test: Dataset({
#         features: ['question_id', 'image', 'question', 'answer', 'id', 'license', 'file_name', 'coco_url', 'height', 'width', 'date_captured'],
#         num_rows: 40670
#     })
# })

# %%
coco['val']
# Out:
# Dataset({
#     features: ['question_id', 'image', 'question', 'answer', 'id', 'license', 'file_name', 'coco_url', 'height', 'width', 'date_captured'],
#     num_rows: 5000
# })

# %%
cap = dsets.CocoCaptions('D:\\dset-finetune\\imgs', 'D:\\dset-finetune\\ann.json', transforms.PILToTensor())
print(f'Number of samples: {len(cap)}')
img, target = cap[0]
print(f'Image size: {img.size()}')
print(target)
# Out:
# loading annotations into memory...
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 cap = dsets.CocoCaptions('D:\\dset-finetune\\imgs', 'D:\\dset-finetune\\ann.json', transforms.PILToTensor())
#       2 print(f'Number of samples: {len(cap)}')
#       3 img, target = cap[0]
#
# File c:\Users\Bui Thien Nghia\AppData\Local\Programs\Python\Python313\Lib\site-packages\torchvision\datasets\coco.py:38, in CocoDetection.__init__(self, root, annFile, transform, target_transform, transforms)
#      35 super().__init__(root, transforms, transform, target_transform)
#      36 from pycocotools.coco import COCO
# ---> 38 self.coco = COCO(annFile)
#      39 self.ids = list(sorted(self.coco.imgs.keys()))
#
# File c:\Users\Bui Thien Nghia\AppData\Local\Programs\Python\Python313\Lib\site-packages\pycocotools\coco.py:82, in COCO.__init__(self, annotation_file)
# ...

# %%
model
# Out:
# CLIP(
#   (visual): VisionTransformer(
#     (conv1): Conv2d(3, 1280, kernel_size=(14, 14), stride=(14, 14), bias=False)
#     (patch_dropout): Identity()
#     (ln_pre): LayerNorm((1280,), eps=1e-05, elementwise_affine=True)
#     (transformer): Transformer(
#       (resblocks): ModuleList(
#         (0-31): 32 x ResidualAttentionBlock(
#           (ln_1): LayerNorm((1280,), eps=1e-05, elementwise_affine=True)
#           (attn): MultiheadAttention(
#             (out_proj): NonDynamicallyQuantizableLinear(in_features=1280, out_features=1280, bias=True)
#           )
#           (ls_1): Identity()
#           (ln_2): LayerNorm((1280,), eps=1e-05, elementwise_affine=True)
#           (mlp): Sequential(
#             (c_fc): Linear(in_features=1280, out_features=5120, bias=True)
#             (gelu): QuickGELU()
#             (c_proj): Linear(in_features=5120, out_features=1280, bias=True)
#           )
#           (ls_2): Identity()
#         )
#       )
#     )
# ...

# %%
TXT_TRANS = model.transformer
IMG_TRANS = model.visual
class Finetuned(nn.Module):
    def __init__(self, txt_trans, img_trans):
        self.txt_trans = txt_trans
        self.img_trans = img_trans

    def forward(self, data):
# Out:
# Conv2d(3, 1280, kernel_size=(14, 14), stride=(14, 14), bias=False)
